# %% [markdown]
# ------Crimeのデータについて------
#
# 手順 1, 犯罪辞書と照合し，分類する
#
# 手順 2, 各年のcrime2020～2024を縦結合
#
# 手順 3, 年別，コミュニティエリア別の集計表を作る
#
#
# ------ACSのデータについて--------
#
# 手順 1, Tractごとのデータからコミュニティx年別のデータの集計表を作成する
#
# 手順 2, ヘッダー(年ｘコミュニティ人口の表)に結合
#
#
# ------最後に------------------
#
# 手順 1, 上記2つのデータセットを結合して完成

# %%
import pandas as pd
import numpy as np

# まずは，crime のデータに分類辞書を結合する

crime_dict = pd.read_csv(r"crime_dictionary.csv")
# yearlist = range(2020, 2024+1)
# for year in yearlist:  後でforループに変更する

year = 2024
df = pd.read_csv(rf"Crimes{year}.csv")

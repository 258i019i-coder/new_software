# %% [markdown]
# ## 年毎の犯罪件数データ(Community集計)を結合する

# %%
import pandas as pd

# %%
# df2002 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2002.csv")
df2003 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2003.csv")
df2004 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2004.csv")
df2005 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2005.csv")
df2006 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2006.csv")
df2007 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2007.csv")
df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
df2009 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2009.csv")
df2010 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2010.csv")
df2011 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2011.csv")
df2012 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2012.csv")
df2013 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2013.csv")
df2014 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2014.csv")
df2015 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2015.csv")
df2016 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2016.csv")
df2017 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2017.csv")
df2018 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2018.csv")
df2019 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2019.csv")
df2020 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2020.csv")
df2021 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2021.csv")
df2022 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2022.csv")
df2023 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2023.csv")
df2024 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2024.csv")
df2025 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2025.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")
# df2008 = pd.read_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_community_area2008.csv")

# %%
df_list = [
    df2003,
    df2004,
    df2005,
    df2006,
    df2007,
    df2008,
    df2009,
    df2010,
    df2011,
    df2012,
    df2013,
    df2014,
    df2015,
    df2016,
    df2017,
    df2018,
    df2019,
    df2020,
    df2021,
    df2022,
    df2023,
    df2024,
    df2025
]

crime_series = pd.concat(df_list, ignore_index=True)

# %%
# for df in df_list:
#     print(df.columns.nunique())

# %%
crime_series.columns.nunique()
# Out:
# 66

# %%
pd.set_option("display.max_rows", None)
crime_series.isna().sum()
# Out:
# year                                    0
# community_area                          0
# other1                                  0
# property1                               0
# public_order1                           0
# violent1                                0
# child3                                  0
# minor_offence3                          0
# minor_offences3                         0
# moral3                                  0
# narcotics3                              0
# others3                                 0
# property3                               0
# sexual3                                 0
# violent3                                0
# weapons3                                0
# white_collar3                           0
# manufacture_deliver                     0
# possess                                 0
# other1_arrest_rate                      0
# property1_arrest_rate                   0
# public_order1_arrest_rate               0
# ...

# %%
# crime_series[crime_series["moral3_arrest_rate"] == 0]

# %%
crime_series.to_csv(r"D:\JupyterLab Cleaned File\CommunityレベルCrime\Crime_Community2003-2025.csv", index = False)
